# %%
import pandas as pd

df1 = pd.read_csv('/content/1_Ocupación_total_diaria hospitales por fractura de cadera.csv')
df2 = pd.read_csv('/content/2_Ocupación_total_diaria hospitales_insuf_cardiaca.csv')
df3 = pd.read_csv('/content/3_Ocupación_total_diaria_hospitalaria_infarto_agudo_miorcardio.csv')
df4 = pd.read_csv('/content/4_Ocupación_total_diaria_hosp_ictus.csv')
df5 = pd.read_csv('/content/5_Ocupación_total_diaria_hosp_epoc.csv')

display(df1.head())
display(df2.head())
display(df3.head())
display(df4.head())
display(df5.head())
# Out:
#   fecha_hosp_cad       Hospital  Occupancy
# 0     2021-10-28  C.A.U. Burgos          1
# 1     2021-10-29  C.A.U. Burgos          1
# 2     2021-10-30  C.A.U. Burgos          1
# 3     2021-10-31  C.A.U. Burgos          1
# 4     2021-11-01  C.A.U. Burgos          1
#   fecha_hosp_insuf_cardiaca          Hospital  Occupancy
# 0                2021-11-17  C.A.U. Salamanca          1
# 1                2021-11-18  C.A.U. Salamanca          1
# 2                2021-11-19  C.A.U. Salamanca          1
# 3                2021-11-20  C.A.U. Salamanca          1
# 4                2021-11-21       C.A.U. León          1
#   fecha_infarto_miorcardio     Hospital  Occupancy
# 0               2021-10-23  C.A.U. León          1
# 1               2021-10-24  C.A.U. León          1
# 2               2021-10-25  C.A.U. León          1
# 3               2021-10-26  C.A.U. León          1
# 4               2021-10-27  C.A.U. León          1
#   fecha_hosp_ictus       Hospital  Occupancy
# 0       2021-10-02  C.A.U. Burgos          1
# 1       2021-10-03  C.A.U. Burgos          1
# 2       2021-10-04  C.A.U. Burgos          1
# 3       2021-10-05  C.A.U. Burgos          1
# 4       2021-10-06  C.A.U. Burgos          1
#   fecha_hosp_epoc           Hospital  Occupancy
# 0      2021-10-21  H.C.U. Valladolid          1
# 1      2021-10-22  H.C.U. Valladolid          1
# 2      2021-10-23  H.C.U. Valladolid          1
# 3      2021-10-24  H.C.U. Valladolid          1
# 4      2021-10-25  H.C.U. Valladolid          1

# %%
df1 = df1.rename(columns={'Occupancy': 'Hosp_fract_cadera'})
display(df1.head())
# Out:
#   fecha_hosp_cad       Hospital  Hosp_fract_cadera
# 0     2021-10-28  C.A.U. Burgos                  1
# 1     2021-10-29  C.A.U. Burgos                  1
# 2     2021-10-30  C.A.U. Burgos                  1
# 3     2021-10-31  C.A.U. Burgos                  1
# 4     2021-11-01  C.A.U. Burgos                  1

# %%
df2 = df2.rename(columns={'Occupancy': 'Hosp_insuf_card'})
df3 = df3.rename(columns={'Occupancy': 'Hosp_infarto_miorardio'})
df4 = df4.rename(columns={'Occupancy': 'Hosp_ictus'})
df5 = df5.rename(columns={'Occupancy': 'Hosp_epoc'})

# %%
date_col_mapping = {
    'fecha_hosp_cad': 'Date',
    'fecha_hosp_insuf_cardiaca': 'Date',
    'fecha_infarto_miorcardio': 'Date',
    'fecha_hosp_ictus': 'Date',
    'fecha_hosp_epoc': 'Date'
}

df1 = df1.rename(columns=date_col_mapping)
df2 = df2.rename(columns=date_col_mapping)
df3 = df3.rename(columns=date_col_mapping)
df4 = df4.rename(columns=date_col_mapping)
df5 = df5.rename(columns=date_col_mapping)

merged_df = pd.merge(df1, df2, on=['Date', 'Hospital'], how='outer')
merged_df = pd.merge(merged_df, df3, on=['Date', 'Hospital'], how='outer')
merged_df = pd.merge(merged_df, df4, on=['Date', 'Hospital'], how='outer')
merged_df = pd.merge(merged_df, df5, on=['Date', 'Hospital'], how='outer')

merged_df = merged_df.fillna(0)

display(merged_df.tail(20))
# Out:
#              Date             Hospital  Hosp_fract_cadera  Hosp_insuf_card  \
# 17953  2025-05-30        C.A.U. Burgos                0.0              1.0
# 17954  2025-05-30          C.A.U. León                0.0              8.0
# 17955  2025-05-30      C.A.U. Palencia                1.0              4.0
# 17956  2025-05-30     C.A.U. Salamanca                2.0              5.0
# 17957  2025-05-30  H. Santiago Apóstol                1.0              3.0
# 17958  2025-05-30      H. Santos Reyes                0.0              0.0
# 17959  2025-05-30    H.C.U. Valladolid                1.0              3.0
# 17960  2025-05-30     H.U. Río Hortega                1.0              0.0
# 17961  2025-05-31         C.A. Segovia                0.0              0.0
# 17962  2025-05-31           C.A. Soria                0.0              1.0
# 17963  2025-05-31          C.A. Zamora                1.0              1.0
# 17964  2025-05-31           C.A. Ávila                0.0              0.0
# 17965  2025-05-31        C.A.U. Burgos                0.0              0.0
# 17966  2025-05-31          C.A.U. León                0.0              0.0
# 17967  2025-05-31      C.A.U. Palencia                0.0              0.0
# 17968  2025-05-31     C.A.U. Salamanca                1.0              0.0
# 17969  2025-05-31  H. Santiago Apóstol                0.0              2.0
# 17970  2025-05-31      H. Santos Reyes                0.0              0.0
# 17971  2025-05-31    H.C.U. Valladolid                0.0              0.0
# 17972  2025-05-31     H.U. Río Hortega                0.0              0.0
#
#        Hosp_infarto_miorardio  Hosp_ictus  Hosp_epoc
# 17953                     3.0         3.0        3.0
# 17954                     0.0         6.0        6.0
# 17955                     0.0         3.0        3.0
# 17956                     2.0         5.0        2.0
# 17957                     0.0         0.0        1.0
# 17958                     1.0         0.0        0.0
# 17959                     2.0         3.0        0.0
# 17960                     2.0         7.0        4.0
# 17961                     0.0         1.0        1.0
# 17962                     0.0         0.0        0.0
# 17963                     0.0         1.0        0.0
# 17964                     0.0         0.0        1.0
# 17965                     2.0         0.0        1.0
# 17966                     1.0         1.0        1.0
# 17967                     0.0         1.0        0.0
# 17968                     0.0         0.0        0.0
# 17969                     0.0         0.0        0.0
# 17970                     1.0         0.0        0.0
# 17971                     2.0         1.0        0.0
# 17972                     0.0         0.0        1.0

# %%
merged_df.to_csv('ocupaciones varias en hospital.csv', index=False)

# %%
# 1. Cargar los archivos
df1 = pd.read_csv("/content/ocupaciones varias en hospital.csv")
df2 = pd.read_csv("/content/ocupacion-de-camas-en-hospitales.csv", sep=";")

# 2. Estandarizar nombres de columnas
df1.columns = df1.columns.str.lower()
df2.columns = df2.columns.str.lower()

# 3. Convertir las fechas al mismo formato
df1['date'] = pd.to_datetime(df1['date'])
df2['fecha'] = pd.to_datetime(df2['fecha'], dayfirst=True)

# 4. Renombrar hospitales para que coincidan
mapa_hospitales = {
    'C.A.U. Burgos': 'Complejo Asistencial Universitario de Burgos',
    'C.A.U. León': 'Complejo Asistencial Universitario de León',
    'C.A.U. Palencia': 'Complejo Asistencial Universitario de Palencia',
    'C.A.U. Salamanca': 'Complejo Asistencial Universitario de Salamanca',
    'C.A. Segovia': 'Complejo Asistencial de Segovia',
    'C.A. Soria': 'Complejo Asistencial de Soria',
    'C.A. Zamora': 'Complejo Asistencial de Zamora',
    'C.A. Ávila': 'Complejo Asistencial de Ávila',
    'H. El Bierzo': 'Hospital El Bierzo',
    'H. Medina del Campo': 'Hospital Medina del Campo',
    'H. Santiago Apóstol': 'Hospital Santiago Apóstol',
    'H. Santos Reyes': 'Hospital Santos Reyes',
    'H.C.U. Valladolid': 'Hospital Clínico Universitario de Valladolid',
    'H.U. Río Hortega': 'Hospital Universitario Río Hortega'
}

df1['hospital'] = df1['hospital'].replace(mapa_hospitales)

# 5. Renombrar columnas para que coincidan
df1 = df1.rename(columns={'date': 'fecha'})
# ya ambas tienen: fecha, hospital

# 6. Unir los datasets
df_merged = pd.merge(df1, df2, on=['fecha', 'hospital'], how='inner')

# 7. Mostrar resultado
print("Filas combinadas:", len(df_merged))
df_merged.info()
# Out:
# Filas combinadas: 16295
#        fecha                                      hospital  hosp_fract_cadera  \
# 0 2021-10-02  Complejo Asistencial Universitario de Burgos                0.0
# 1 2021-10-03  Complejo Asistencial Universitario de Burgos                0.0
# 2 2021-10-04  Complejo Asistencial Universitario de Burgos                0.0
# 3 2021-10-05  Complejo Asistencial Universitario de Burgos                0.0
# 4 2021-10-06  Complejo Asistencial Universitario de Burgos                0.0
#
#    hosp_insuf_card  hosp_infarto_miorardio  hosp_ictus  hosp_epoc provincia  \
# 0              0.0                     0.0         1.0        0.0    Burgos
# 1              0.0                     0.0         1.0        0.0    Burgos
# 2              0.0                     0.0         1.0        0.0    Burgos
# 3              0.0                     0.0         1.0        0.0    Burgos
# 4              0.0                     0.0         1.0        0.0    Burgos
#
#    camas_iniciales_planta  camas_habilitadas_planta  camas_ocupadas_planta  \
# 0                   842.0                     754.0                  459.0
# 1                   842.0                     755.0                  458.0
# 2                   842.0                     753.0                  491.0
# 3                   842.0                     754.0                  516.0
# 4                   842.0                     752.0                  532.0
#
#    camas_iniciales_uci  camas_habilitadas_uci  camas_ocupadas_uci  \
# 0                 42.0                   45.0                33.0
# 1                 42.0                   45.0                33.0
# 2                 42.0                   45.0                35.0
# 3                 42.0                   45.0                36.0
# 4                 42.0                   45.0                35.0
#
#    camas_ocupadas_covid_uci  codigo_ine
# 0                       3.0        9059
# 1                       3.0        9059
# 2                       3.0        9059
# 3                       3.0        9059
# 4                       3.0        9059

# %%
df['provincia'].unique
# Out:
# <bound method Series.unique of 0        Burgos
# 1        Burgos
# 2        Burgos
# 3        Burgos
# 4        Burgos
#           ...
# 12541    Zamora
# 12542    Zamora
# 12543    Zamora
# 12544    Zamora
# 12545    Zamora
# Name: provincia, Length: 12546, dtype: object>

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16295 entries, 0 to 16294
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   fecha                     16295 non-null  datetime64[ns]
#  1   hospital                  16295 non-null  object
#  2   hosp_fract_cadera         16295 non-null  float64
#  3   hosp_insuf_card           16295 non-null  float64
#  4   hosp_infarto_miorardio    16295 non-null  float64
#  5   hosp_ictus                16295 non-null  float64
#  6   hosp_epoc                 16295 non-null  float64
#  7   provincia                 16295 non-null  object
#  8   camas_iniciales_planta    16295 non-null  float64
#  9   camas_habilitadas_planta  16295 non-null  float64
#  10  camas_ocupadas_planta     16295 non-null  float64
#  11  camas_iniciales_uci       16295 non-null  float64
#  12  camas_habilitadas_uci     16295 non-null  float64
#  13  camas_ocupadas_uci        16295 non-null  float64
#  14  camas_ocupadas_covid_uci  16295 non-null  float64
#  15  codigo_ine                16295 non-null  int64
# dtypes: datetime64[ns](1), float64(12), int64(1), object(2)
# memory usage: 2.0+ MB

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

API_KEY = "72c6cd939a3d48aeaee113650251410"

provincias = ['Burgos', 'Palencia', 'Valladolid', 'Ávila', 'León',
              'Salamanca', 'Soria', 'Segovia', 'Zamora']

start_date = datetime(2022, 1, 1)
end_date = datetime(2025, 10, 25)

url_base = "https://api.worldweatheronline.com/premium/v1/past-weather.ashx"
data_all = []

# Función para obtener datos de una provincia en un rango corto
def get_weather(provincia, start, end):
    params = {
        "key": API_KEY,
        "q": f"{provincia}, Spain",
        "format": "json",
        "date": start.strftime("%Y-%m-%d"),
        "enddate": end.strftime("%Y-%m-%d"),
        "tp": "24"
    }

    response = requests.get(url_base, params=params)
    if response.status_code == 200:
        data = response.json()
        if 'data' in data and 'weather' in data['data']:
            for day in data['data']['weather']:
                data_all.append({
                    "provincia": provincia,
                    "fecha": day['date'],
                    "tmax": day['maxtempC'],
                    "tmin": day['mintempC'],
                    "precip_mm": day['hourly'][0]['precipMM'],
                    "humedad_%": day['hourly'][0]['humidity'],
                    "viento_kph": day['hourly'][0]['windspeedKmph']
                })
    else:
        print(f"Error en {provincia}: {response.status_code}")

# Bucle por provincias y meses
for prov in provincias:
    current = start_date
    while current < end_date:
        next_date = current + timedelta(days=30)
        if next_date > end_date:
            next_date = end_date
        print(f"Descargando {prov} desde {current.date()} hasta {next_date.date()}...")
        get_weather(prov, current, next_date)
        current = next_date + timedelta(days=1)

# Crear DataFrame
df = pd.DataFrame(data_all)
df['fecha'] = pd.to_datetime(df['fecha'])

# Guardar a CSV
df.to_csv("clima_castilla_y_leon_2022_2025.csv", index=False)

print("✅ Descarga completada. Archivo guardado como clima_castilla_y_leon_2022_2025.csv")
# Out:
# Descargando Burgos desde 2022-01-01 hasta 2022-01-31...
# Descargando Burgos desde 2022-02-01 hasta 2022-03-03...
# Descargando Burgos desde 2022-03-04 hasta 2022-04-03...
# Descargando Zamora desde 2024-12-21 hasta 2025-01-20...
# Descargando Zamora desde 2025-01-21 hasta 2025-02-20...
# Descargando Zamora desde 2025-02-21 hasta 2025-03-23...
# Descargando Zamora desde 2025-03-24 hasta 2025-04-23...
# Descargando Zamora desde 2025-04-24 hasta 2025-05-24...
# Descargando Zamora desde 2025-05-25 hasta 2025-06-24...
# Descargando Zamora desde 2025-06-25 hasta 2025-07-25...
# Descargando Zamora desde 2025-07-26 hasta 2025-08-25...
# Descargando Zamora desde 2025-08-26 hasta 2025-09-25...
# Descargando Zamora desde 2025-09-26 hasta 2025-10-25...
# ✅ Descarga completada. Archivo guardado como clima_castilla_y_leon_2022_2025.csv

# %%
df.head()
# Out:
#   provincia      fecha tmax tmin precip_mm humedad_% viento_kph
# 0    Burgos 2022-01-01   15    4       0.0        54         11
# 1    Burgos 2022-01-02   13    6       0.0        63         13
# 2    Burgos 2022-01-03   13    6       0.0        83         14
# 3    Burgos 2022-01-04   12    3      10.1        81         19
# 4    Burgos 2022-01-05    3   -1       5.9        90         11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12546 entries, 0 to 12545
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   provincia   12546 non-null  object
#  1   fecha       12546 non-null  datetime64[ns]
#  2   tmax        12546 non-null  object
#  3   tmin        12546 non-null  object
#  4   precip_mm   12546 non-null  object
#  5   humedad_%   12546 non-null  object
#  6   viento_kph  12546 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 686.2+ KB

# %%
merged_df_final = pd.merge(df_merged, df, on=['fecha', 'provincia'], how='left')
display(merged_df_final.head())
# Out:
#        fecha                                      hospital  hosp_fract_cadera  \
# 0 2021-10-02  Complejo Asistencial Universitario de Burgos                0.0
# 1 2021-10-03  Complejo Asistencial Universitario de Burgos                0.0
# 2 2021-10-04  Complejo Asistencial Universitario de Burgos                0.0
# 3 2021-10-05  Complejo Asistencial Universitario de Burgos                0.0
# 4 2021-10-06  Complejo Asistencial Universitario de Burgos                0.0
#
#    hosp_insuf_card  hosp_infarto_miorardio  hosp_ictus  hosp_epoc provincia  \
# 0              0.0                     0.0         1.0        0.0    Burgos
# 1              0.0                     0.0         1.0        0.0    Burgos
# 2              0.0                     0.0         1.0        0.0    Burgos
# 3              0.0                     0.0         1.0        0.0    Burgos
# 4              0.0                     0.0         1.0        0.0    Burgos
#
#    camas_iniciales_planta  camas_habilitadas_planta  ...  camas_iniciales_uci  \
# 0                   842.0                     754.0  ...                 42.0
# 1                   842.0                     755.0  ...                 42.0
# 2                   842.0                     753.0  ...                 42.0
# 3                   842.0                     754.0  ...                 42.0
# 4                   842.0                     752.0  ...                 42.0
#
#    camas_habilitadas_uci  camas_ocupadas_uci  camas_ocupadas_covid_uci  \
# 0                   45.0                33.0                       3.0
# 1                   45.0                33.0                       3.0
# 2                   45.0                35.0                       3.0
# 3                   45.0                36.0                       3.0
# 4                   45.0                35.0                       3.0
#
#    codigo_ine  tmax tmin precip_mm humedad_% viento_kph
# 0        9059   NaN  NaN       NaN       NaN        NaN
# 1        9059   NaN  NaN       NaN       NaN        NaN
# 2        9059   NaN  NaN       NaN       NaN        NaN
# 3        9059   NaN  NaN       NaN       NaN        NaN
# 4        9059   NaN  NaN       NaN       NaN        NaN
#
# [5 rows x 21 columns]

# %%
merged_df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16295 entries, 0 to 16294
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   fecha                     16295 non-null  datetime64[ns]
#  1   hospital                  16295 non-null  object
#  2   hosp_fract_cadera         16295 non-null  float64
#  3   hosp_insuf_card           16295 non-null  float64
#  4   hosp_infarto_miorardio    16295 non-null  float64
#  5   hosp_ictus                16295 non-null  float64
#  6   hosp_epoc                 16295 non-null  float64
#  7   provincia                 16295 non-null  object
#  8   camas_iniciales_planta    16295 non-null  float64
#  9   camas_habilitadas_planta  16295 non-null  float64
#  10  camas_ocupadas_planta     16295 non-null  float64
#  11  camas_iniciales_uci       16295 non-null  float64
#  12  camas_habilitadas_uci     16295 non-null  float64
#  13  camas_ocupadas_uci        16295 non-null  float64
#  14  camas_ocupadas_covid_uci  16295 non-null  float64
#  15  codigo_ine                16295 non-null  int64
#  16  tmax                      15764 non-null  object
#  17  tmin                      15764 non-null  object
#  18  precip_mm                 15764 non-null  object
#  19  humedad_%                 15764 non-null  object
#  20  viento_kph                15764 non-null  object
# dtypes: datetime64[ns](1), float64(12), int64(1), object(7)
# memory usage: 2.6+ MB

# %%
merged_df_final.to_csv('camas_hosp_clima.csv', index=False)

# %%
merged_df_final['fecha'] = pd.to_datetime(merged_df_final['fecha'])

filtered_merged_df_final = merged_df_final[merged_df_final['fecha'] >= '2022-01-01'].copy()

# Convert columns to float, coercing errors
cols_to_convert = ['tmax', 'tmin', 'precip_mm', 'humedad_%', 'viento_kph']
for col in cols_to_convert:
    filtered_merged_df_final[col] = pd.to_numeric(filtered_merged_df_final[col], errors='coerce')


display(filtered_merged_df_final.head())
filtered_merged_df_final.info()
# Out:
#          fecha                                      hospital  \
# 531 2022-01-01               Complejo Asistencial de Segovia
# 532 2022-01-01                 Complejo Asistencial de Soria
# 533 2022-01-01                Complejo Asistencial de Zamora
# 534 2022-01-01                 Complejo Asistencial de Ávila
# 535 2022-01-01  Complejo Asistencial Universitario de Burgos
#
#      hosp_fract_cadera  hosp_insuf_card  hosp_infarto_miorardio  hosp_ictus  \
# 531                4.0             10.0                     5.0         7.0
# 532                3.0              4.0                     0.0         3.0
# 533                4.0             17.0                     5.0         5.0
# 534                1.0             26.0                     1.0         8.0
# 535                8.0             45.0                     2.0        12.0
#
#      hosp_epoc provincia  camas_iniciales_planta  camas_habilitadas_planta  \
# 531        7.0   Segovia                   365.0                     325.0
# 532        1.0     Soria                   319.0                     274.0
# 533       10.0    Zamora                   395.0                     358.0
# 534       13.0     Ávila                   422.0                     368.0
# 535       15.0    Burgos                   842.0                     755.0
#
#      ...  camas_iniciales_uci  camas_habilitadas_uci  camas_ocupadas_uci  \
# 531  ...                 16.0                   31.0                12.0
# 532  ...                 14.0                   14.0                 9.0
# 533  ...                 17.0                   19.0                 8.0
# 534  ...                 14.0                   18.0                 9.0
# 535  ...                 42.0                   47.0                38.0
#
#      camas_ocupadas_covid_uci  codigo_ine  tmax  tmin  precip_mm  humedad_%  \
# 531                       5.0       40004    17     8        0.0         41
# 532                       5.0       42173    15     2        0.0         52
# 533                       4.0       49275    16     4        0.0         59
# 534                       4.0        5019    20     5        0.0         49
# 535                      13.0        9059    15     4        0.0         54
#
#      viento_kph
# 531           6
# 532           6
# 533           7
# 534           8
# 535          11
#
# [5 rows x 21 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 15764 entries, 531 to 16294
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   fecha                     15764 non-null  datetime64[ns]
#  1   hospital                  15764 non-null  object
#  2   hosp_fract_cadera         15764 non-null  float64
#  3   hosp_insuf_card           15764 non-null  float64
#  4   hosp_infarto_miorardio    15764 non-null  float64
#  5   hosp_ictus                15764 non-null  float64
#  6   hosp_epoc                 15764 non-null  float64
#  7   provincia                 15764 non-null  object
#  8   camas_iniciales_planta    15764 non-null  float64
#  9   camas_habilitadas_planta  15764 non-null  float64
#  10  camas_ocupadas_planta     15764 non-null  float64
#  11  camas_iniciales_uci       15764 non-null  float64
#  12  camas_habilitadas_uci     15764 non-null  float64
#  13  camas_ocupadas_uci        15764 non-null  float64
#  14  camas_ocupadas_covid_uci  15764 non-null  float64
#  15  codigo_ine                15764 non-null  int64
#  16  tmax                      15764 non-null  int64
#  17  tmin                      15764 non-null  int64
#  18  precip_mm                 15764 non-null  float64
#  19  humedad_%                 15764 non-null  int64
#  20  viento_kph                15764 non-null  int64
# dtypes: datetime64[ns](1), float64(13), int64(5), object(2)
# memory usage: 2.6+ MB

# %%
filtered_merged_df_final.to_csv('camas_hosp_clima.csv', index=False)

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder


# Columna a codificar
cols_to_encode = ['hospital', 'provincia']

# Crear instancia OneHotEncoder
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# Ajustar y transformar la columna seleccionada
encoded_cols = encoder.fit_transform(filtered_merged_df_final[cols_to_encode])

# Crear el dataframe
encoded_col_names = encoder.get_feature_names_out(cols_to_encode)
encoded_df_part = pd.DataFrame(encoded_cols, columns=encoded_col_names, index=filtered_merged_df_final.index)

# Elimniar las columnas originales
encoded_df = filtered_merged_df_final.drop(columns=cols_to_encode).copy()
encoded_df = pd.concat([encoded_df, encoded_df_part], axis=1)

display(encoded_df.head())
encoded_df.info()
# Out:
#          fecha  hosp_fract_cadera  hosp_insuf_card  hosp_infarto_miorardio  \
# 531 2022-01-01                4.0             10.0                     5.0
# 532 2022-01-01                3.0              4.0                     0.0
# 533 2022-01-01                4.0             17.0                     5.0
# 534 2022-01-01                1.0             26.0                     1.0
# 535 2022-01-01                8.0             45.0                     2.0
#
#      hosp_ictus  hosp_epoc  camas_iniciales_planta  camas_habilitadas_planta  \
# 531         7.0        7.0                   365.0                     325.0
# 532         3.0        1.0                   319.0                     274.0
# 533         5.0       10.0                   395.0                     358.0
# 534         8.0       13.0                   422.0                     368.0
# 535        12.0       15.0                   842.0                     755.0
#
#      camas_ocupadas_planta  camas_iniciales_uci  ...  \
# 531                  167.0                 16.0  ...
# 532                  131.0                 14.0  ...
# 533                  265.0                 17.0  ...
# 534                  196.0                 14.0  ...
# 535                  457.0                 42.0  ...
#
#      hospital_Hospital Universitario Río Hortega  provincia_Burgos  \
# 531                                          0.0               0.0
# 532                                          0.0               0.0
# 533                                          0.0               0.0
# 534                                          0.0               0.0
# 535                                          0.0               1.0
#
#      provincia_León  provincia_Palencia  provincia_Salamanca  \
# 531             0.0                 0.0                  0.0
# 532             0.0                 0.0                  0.0
# 533             0.0                 0.0                  0.0
# 534             0.0                 0.0                  0.0
# 535             0.0                 0.0                  0.0
#
#      provincia_Segovia  provincia_Soria  provincia_Valladolid  \
# 531                1.0              0.0                   0.0
# 532                0.0              1.0                   0.0
# 533                0.0              0.0                   0.0
# 534                0.0              0.0                   0.0
# 535                0.0              0.0                   0.0
#
#      provincia_Zamora  provincia_Ávila
# 531               0.0              0.0
# 532               0.0              0.0
# 533               1.0              0.0
# 534               0.0              1.0
# 535               0.0              0.0
#
# [5 rows x 41 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 15764 entries, 531 to 16294
# Data columns (total 41 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   fecha                                                     15764 non-null  datetime64[ns]
#  1   hosp_fract_cadera                                         15764 non-null  float64
#  2   hosp_insuf_card                                           15764 non-null  float64
#  3   hosp_infarto_miorardio                                    15764 non-null  float64
#  4   hosp_ictus                                                15764 non-null  float64
#  5   hosp_epoc                                                 15764 non-null  float64
#  6   camas_iniciales_planta                                    15764 non-null  float64
#  7   camas_habilitadas_planta                                  15764 non-null  float64
#  8   camas_ocupadas_planta                                     15764 non-null  float64
#  9   camas_iniciales_uci                                       15764 non-null  float64
#  10  camas_habilitadas_uci                                     15764 non-null  float64
#  11  camas_ocupadas_uci                                        15764 non-null  float64
#  12  camas_ocupadas_covid_uci                                  15764 non-null  float64
#  13  codigo_ine                                                15764 non-null  int64
#  14  tmax                                                      15764 non-null  int64
#  15  tmin                                                      15764 non-null  int64
#  16  precip_mm                                                 15764 non-null  float64
#  17  humedad_%                                                 15764 non-null  int64
#  18  viento_kph                                                15764 non-null  int64
#  19  hospital_Complejo Asistencial Universitario de Burgos     15764 non-null  float64
#  20  hospital_Complejo Asistencial Universitario de León       15764 non-null  float64
#  21  hospital_Complejo Asistencial Universitario de Palencia   15764 non-null  float64
#  22  hospital_Complejo Asistencial Universitario de Salamanca  15764 non-null  float64
#  23  hospital_Complejo Asistencial de Segovia                  15764 non-null  float64
#  24  hospital_Complejo Asistencial de Soria                    15764 non-null  float64
#  25  hospital_Complejo Asistencial de Zamora                   15764 non-null  float64
#  26  hospital_Complejo Asistencial de Ávila                    15764 non-null  float64
#  27  hospital_Hospital Clínico Universitario de Valladolid     15764 non-null  float64
#  28  hospital_Hospital El Bierzo                               15764 non-null  float64
#  29  hospital_Hospital Santiago Apóstol                        15764 non-null  float64
#  30  hospital_Hospital Santos Reyes                            15764 non-null  float64
#  31  hospital_Hospital Universitario Río Hortega               15764 non-null  float64
#  32  provincia_Burgos                                          15764 non-null  float64
#  33  provincia_León                                            15764 non-null  float64
#  34  provincia_Palencia                                        15764 non-null  float64
#  35  provincia_Salamanca                                       15764 non-null  float64
#  36  provincia_Segovia                                         15764 non-null  float64
#  37  provincia_Soria                                           15764 non-null  float64
#  38  provincia_Valladolid                                      15764 non-null  float64
#  39  provincia_Zamora                                          15764 non-null  float64
#  40  provincia_Ávila                                           15764 non-null  float64
# dtypes: datetime64[ns](1), float64(35), int64(5)
# memory usage: 5.1 MB

# %%
encoded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15764 entries, 531 to 16294
# Data columns (total 41 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   fecha                                                     15764 non-null  datetime64[ns]
#  1   hosp_fract_cadera                                         15764 non-null  float64
#  2   hosp_insuf_card                                           15764 non-null  float64
#  3   hosp_infarto_miorardio                                    15764 non-null  float64
#  4   hosp_ictus                                                15764 non-null  float64
#  5   hosp_epoc                                                 15764 non-null  float64
#  6   camas_iniciales_planta                                    15764 non-null  float64
#  7   camas_habilitadas_planta                                  15764 non-null  float64
#  8   camas_ocupadas_planta                                     15764 non-null  float64
#  9   camas_iniciales_uci                                       15764 non-null  float64
#  10  camas_habilitadas_uci                                     15764 non-null  float64
#  11  camas_ocupadas_uci                                        15764 non-null  float64
#  12  camas_ocupadas_covid_uci                                  15764 non-null  float64
#  13  codigo_ine                                                15764 non-null  int64
#  14  tmax                                                      15764 non-null  int64
#  15  tmin                                                      15764 non-null  int64
#  16  precip_mm                                                 15764 non-null  float64
#  17  humedad_%                                                 15764 non-null  int64
#  18  viento_kph                                                15764 non-null  int64
#  19  hospital_Complejo Asistencial Universitario de Burgos     15764 non-null  float64
#  20  hospital_Complejo Asistencial Universitario de León       15764 non-null  float64
#  21  hospital_Complejo Asistencial Universitario de Palencia   15764 non-null  float64
#  22  hospital_Complejo Asistencial Universitario de Salamanca  15764 non-null  float64
#  23  hospital_Complejo Asistencial de Segovia                  15764 non-null  float64
#  24  hospital_Complejo Asistencial de Soria                    15764 non-null  float64
#  25  hospital_Complejo Asistencial de Zamora                   15764 non-null  float64
#  26  hospital_Complejo Asistencial de Ávila                    15764 non-null  float64
#  27  hospital_Hospital Clínico Universitario de Valladolid     15764 non-null  float64
#  28  hospital_Hospital El Bierzo                               15764 non-null  float64
#  29  hospital_Hospital Santiago Apóstol                        15764 non-null  float64
#  30  hospital_Hospital Santos Reyes                            15764 non-null  float64
#  31  hospital_Hospital Universitario Río Hortega               15764 non-null  float64
#  32  provincia_Burgos                                          15764 non-null  float64
#  33  provincia_León                                            15764 non-null  float64
#  34  provincia_Palencia                                        15764 non-null  float64
#  35  provincia_Salamanca                                       15764 non-null  float64
#  36  provincia_Segovia                                         15764 non-null  float64
#  37  provincia_Soria                                           15764 non-null  float64
#  38  provincia_Valladolid                                      15764 non-null  float64
#  39  provincia_Zamora                                          15764 non-null  float64
#  40  provincia_Ávila                                           15764 non-null  float64
# dtypes: datetime64[ns](1), float64(35), int64(5)
# memory usage: 5.1 MB

# %%
encoded_df.to_csv('camas_hosp_clima_encod.csv', index=False)
